# %% [markdown]
# # Data processing
#
# In this notebook, I am loading a list smiles molecules I obtained from Ersilia summer 2024 internship slack channel and processing the
# - Checking all 1000 smiles are valid smiles
# - Standardzing the smiles

# %%
#import necessary files
import sys
import os
import pandas as pd
import json
import csv

# %%
# Add the src directory to the Python module search path
sys.path.append(os.path.abspath("../src"))

#add the input files path
unprocessed = os.path.abspath('../data/reference_library.csv')
input = os.path.abspath('../data/input.csv')
standardize = os.path.abspath('../data/standardized_smiles.csv')
sample = os.path.abspath('../data/sample_smiles.csv')
output = os.path.abspath('../data/output.csv')
tsion = os.path.abspath('../data/sample_input_inchkey.csv')

# %%
#count valid smiles from 1000 molecules
#import the python function thats checks smiles validity
from src.processing import validate_smiles_in_csv
valid_count, invalid_count = validate_smiles_in_csv(unprocessed)
print(f"Number of valid SMILES: {valid_count}")
print(f"Number of invalid SMILES: {invalid_count}")
# Out:
# Number of valid SMILES: 1000
# Number of invalid SMILES: 0

# %%
#import the python function thats will standardize the smiles
from src.processing import standardise_smiles_from_csv
#standardized and save file
standardise_smiles_from_csv(unprocessed, standardize)
# Out:
# [09:17:17] Can't kekulize mol.  Unkekulized atoms: 3 7
# Number of standardized SMILES: 997

# %%
df = pd.read_csv(standardize)
print(df.head())
# Out:
#                                               smiles  \
# 0                       CCCCNC(=S)N/N=C/C1=C(C)C=CS1
# 1         CN1C(SCC2=NC(C3=CC=CS3)=NO2)=NN=C1C1CCCCC1
# 2           O=C(O)CC(NC(=O)C1=CN=CC=N1)C1=CC=CC=C1Cl
# 3  O=S(=O)(C1=CC=CC=C1)N1CCN(C2=NOC3=CC=CC(Cl)=C2...
# 4  CCC[C@@H](C)N(C1=CC(Cl)=CC=C1CO)S(=O)(=O)C1=CC...
#
#                                  Standardized_SMILES
# 0                           CCCCNC(=S)N/N=C/c1sccc1C
# 1              Cn1c(SCc2nc(-c3cccs3)no2)nnc1C1CCCCC1
# 2                 O=C(O)CC(NC(=O)c1cnccn1)c1ccccc1Cl
# 3       O=S(=O)(c1ccccc1)N1CCN(c2noc3cccc(Cl)c23)CC1
# 4  CCC[C@@H](C)N(c1cc(Cl)ccc1CO)S(=O)(=O)c1ccc(C)cc1

# %%
# Drop the 'smiles' column
df = df.drop('smiles', axis=1)

# Rename the 'Standardized_SMILES' column to 'smiles'
df = df.rename(columns={'Standardized_SMILES': 'smiles'})
#save teh process file as input
df.to_csv(input, index=False)
print(df.head())
# Out:
#                                               smiles
# 0                           CCCCNC(=S)N/N=C/c1sccc1C
# 1              Cn1c(SCc2nc(-c3cccs3)no2)nnc1C1CCCCC1
# 2                 O=C(O)CC(NC(=O)c1cnccn1)c1ccccc1Cl
# 3       O=S(=O)(c1ccccc1)N1CCN(c2noc3cccc(Cl)c23)CC1
# 4  CCC[C@@H](C)N(c1cc(Cl)ccc1CO)S(=O)(=O)c1ccc(C)cc1

# %% [markdown]
# # Running Model
#
# Here I will run the model I've fetched using ersilia -v fetch eos30gr --from_git , since importing the model is giving error(detail can be found in the dedugging ersilia folder) I will be using the terminal input to serve and run the model:
# - Test model with smiles
# - Test model with InChiKey
# - Test model out put to csv file

# %%
# !ersilia serve eos30gr
# Out:
# 🚀 Serving model eos30gr: deepherg
#
#    URL: http://127.0.0.1:40343
#    PID: 9909
#    SRV: conda
#
# 👉 To run model:
#    - run
#
# 💁 Information:
#    - info

# %%
#test model using sample smile file
# !ersilia run -i sample_input_smiles.csv
# Out:
# {
#     "input": {
#         "key": "SUTWUYBMBWPLMW-MDWZMJQESA-N",
#         "input": "CCCCNC(=S)N/N=C/c1sccc1C",
#         "text": "CCCCNC(=S)N/N=C/c1sccc1C"
#     },
#     "output": {
#         "outcome": 0.3471122086048126
#     }
# }

# %%
#outputting result to file
# !ersilia api run -i sample_input_smiles.csv -o output.csv
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/envs/ersilia/bin/ersilia", line 8, in <module>
#     sys.exit(cli())
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/cli/commands/__init__.py", line 22, in wrapper
#     return func(*args, **kwargs)
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/cli/commands/api.py", line 37, in api
#     result = mdl.api(
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/core/model.py", line 387, in api
#     return self.api_task(
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/core/model.py", line 402, in api_task
#     for r in result:
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/core/model.py", line 213, in _api_runner_iter
#     for result in api.post(input=input, output=output, batch_size=batch_size):
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/serve/api.py", line 329, in post
#     self.output_adapter.adapt(
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/io/output.py", line 332, in adapt
#     df = self._to_dataframe(result, model_id)
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/io/output.py", line 274, in _to_dataframe
#     output_keys_expanded = self.__expand_output_keys(vals, output_keys)
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/io/output.py", line 220, in __expand_output_keys
#     if len(m) > len(v):
# TypeError: object of type 'float' has no len()

# %% [markdown]
# Since running output to file is not working i decided to check if i have isaura and confirmed its already installed

# %%
#checkin if isaura is installed
# !python -m pip install isaura==0.1
# Out:
# Requirement already satisfied: isaura==0.1 in /opt/conda/envs/ersilia/lib/python3.10/site-packages (0.1)
# Requirement already satisfied: h5py==3.7.0 in /opt/conda/envs/ersilia/lib/python3.10/site-packages (from isaura==0.1) (3.7.0)
# Requirement already satisfied: loguru==0.6.0 in /opt/conda/envs/ersilia/lib/python3.10/site-packages (from isaura==0.1) (0.6.0)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/envs/ersilia/lib/python3.10/site-packages (from h5py==3.7.0->isaura==0.1) (1.26.4)

# %% [markdown]
# out putting to file is giving type error so i decided to use InChKey and test

# %%
#testing otputting to file with InChKey
# !ersilia api run -i sample_input_inchkey.csv -o output.csv
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/envs/ersilia/bin/ersilia", line 8, in <module>
#     sys.exit(cli())
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/opt/conda/envs/ersilia/lib/python3.10/site-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/cli/commands/__init__.py", line 22, in wrapper
#     return func(*args, **kwargs)
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/cli/commands/api.py", line 37, in api
#     result = mdl.api(
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/core/model.py", line 387, in api
#     return self.api_task(
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/core/model.py", line 402, in api_task
#     for r in result:
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/core/model.py", line 213, in _api_runner_iter
#     for result in api.post(input=input, output=output, batch_size=batch_size):
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/serve/api.py", line 329, in post
#     self.output_adapter.adapt(
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/io/output.py", line 332, in adapt
#     df = self._to_dataframe(result, model_id)
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/io/output.py", line 274, in _to_dataframe
#     output_keys_expanded = self.__expand_output_keys(vals, output_keys)
#   File "/workspaces/codespaces-jupyter/ersilia/ersilia/io/output.py", line 220, in __expand_output_keys
#     if len(m) > len(v):
# TypeError: object of type 'float' has no len()

# %% [markdown]
# The model seems to work file when running with out output option but gives TypeError when trying to save to output

# %%
#testing with out outputting to file
# !ersilia api run -i sample_input_inchkey.csv
# Out:
# {
#     "input": {
#         "key": "BLGXFZZNTVWLAY-SCYLSFHTSA-N",
#         "input": "COC(=O)[C@@H]1[C@H]2C[C@H]3c4[nH]c5ccccc5c4CCN3C[C@@H]2CC[C@@H]1O",
#         "text": "COC(=O)[C@@H]1[C@H]2C[C@H]3c4[nH]c5ccccc5c4CCN3C[C@@H]2CC[C@@H]1O"
#     },
#     "output": {
#         "outcome": 0.39273926615715027
#     }
# }
# {
#     "input": {
#         "key": "BLGXFZZNTVWLAY-SCYLSFHTSA-N",
#         "input": "COC(=O)[C@@H]1[C@H]2C[C@H]3c4[nH]c5ccccc5c4CCN3C[C@@H]2CC[C@@H]1O",
#         "text": "COC(=O)[C@@H]1[C@H]2C[C@H]3c4[nH]c5ccccc5c4CCN3C[C@@H]2CC[C@@H]1O"
#     },
#     "output": {
#         "outcome": 0.39273926615715027
#     }
# }
# {
#     "input": {
#         "key": "BLGXFZZNTVWLAY-SCYLSFHTSA-N",
#         "input": "COC(=O)[C@@H]1[C@H]2C[C@H]3c4[nH]c5ccccc5c4CCN3C[C@@H]2CC[C@@H]1O",
#         "text": "COC(=O)[C@@H]1[C@H]2C[C@H]3c4[nH]c5ccccc5c4CCN3C[C@@H]2CC[C@@H]1O"
#     },
#     "output": {
#         "outcome": 0.39273926615715027
#     }
# }

# %% [markdown]
# # Since -o to output.csv is not wokring i decided to redirect the whole output to a txt file and then process the data

# %%
import os
#redirecting output to file
# !ersilia api run -i sample_input_inchkey.csv > ../data/row_output.txt
file_path = os.path.abspath('../data/row_output.txt')
#preview file
with open(file_path, 'r') as file:
    lines = [next(file) for _ in range(10)]
for line in lines:
    print(line)
# Out:
# {
#
#     "input": {
#
#         "key": "BLGXFZZNTVWLAY-SCYLSFHTSA-N",
#
#         "input": "COC(=O)[C@@H]1[C@H]2C[C@H]3c4[nH]c5ccccc5c4CCN3C[C@@H]2CC[C@@H]1O",
#
#         "text": "COC(=O)[C@@H]1[C@H]2C[C@H]3c4[nH]c5ccccc5c4CCN3C[C@@H]2CC[C@@H]1O"
#
#     },
#
#     "output": {
#
#         "outcome": 0.39273926615715027
#
#     }
#
# }

# %%
# !ersilia api run -i sample_input_inchkey.csv > ../data/row_output.txt

# %%
#now i will extract the inchkey, smiles and outcome and creat a csv file
from src import process_json_file
process_json_file('../data/output.txt', '../fromtext.csv')
# Out:
# Error decoding JSON: Expecting property name enclosed in double quotes: line 2 column 1 (char 2)
# Error decoding JSON: Extra data: line 1 column 12 (char 11)
# Error decoding JSON: Extra data: line 1 column 14 (char 13)
# Error decoding JSON: Extra data: line 1 column 16 (char 15)
# Error decoding JSON: Extra data: line 1 column 15 (char 14)
# Error decoding JSON: Expecting value: line 1 column 5 (char 4)
# Error decoding JSON: Extra data: line 1 column 13 (char 12)
# Error decoding JSON: Extra data: line 1 column 18 (char 17)
# Error decoding JSON: Expecting value: line 1 column 5 (char 4)
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON: Expecting property name enclosed in double quotes: line 2 column 1 (char 2)
# Error decoding JSON: Extra data: line 1 column 12 (char 11)
# Error decoding JSON: Extra data: line 1 column 14 (char 13)
# Error decoding JSON: Extra data: line 1 column 16 (char 15)
# Error decoding JSON: Extra data: line 1 column 15 (char 14)
# Error decoding JSON: Expecting value: line 1 column 5 (char 4)
# Error decoding JSON: Extra data: line 1 column 13 (char 12)
# Error decoding JSON: Extra data: line 1 column 18 (char 17)
# Error decoding JSON: Expecting value: line 1 column 5 (char 4)
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON: Expecting property name enclosed in double quotes: line 2 column 1 (char 2)
# Error decoding JSON: Extra data: line 1 column 12 (char 11)
# Error decoding JSON: Extra data: line 1 column 14 (char 13)
# Error decoding JSON: Extra data: line 1 column 16 (char 15)
# Error decoding JSON: Extra data: line 1 column 15 (char 14)
# Error decoding JSON: Expecting value: line 1 column 5 (char 4)
# Error decoding JSON: Extra data: line 1 column 13 (char 12)
# Error decoding JSON: Extra data: line 1 column 18 (char 17)
# Error decoding JSON: Expecting value: line 1 column 5 (char 4)
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# I kept getting json format errror
# - I validated the json files adn the isseu seem to be that multiple json files are stored in the output.txt file so I tried to use regular expression instead

# %%
import re
import os


def extract_keys_and_values_from_text(file_path):
    key_value_pairs = []
    with open(file_path, 'r') as file:
        text = file.read()
        # Define a regular expression pattern to find key-value pairs
        pattern = r'"key":\s*"(.*?)".*?"input":\s*"(.*?)".*?"outcome":\s*\[\s*(\d+\.\d+)\s*\]'
        matches = re.findall(pattern, text, re.DOTALL)
        for match in matches:
            key_value_pairs.append(("key", match[0]))
            key_value_pairs.append(("input", match[1]))
            key_value_pairs.append(("outcome", float(match[2])))
    return key_value_pairs

file_path = os.path.abspath('../data/row_output.txt')
key_value_pairs = extract_keys_and_values_from_text(file_path)
for key, value in key_value_pairs:
    print(f"Key: {key}, Value: {value}")
# Out:
# Key: key, Value: SUTWUYBMBWPLMW-MDWZMJQESA-N
# Key: input, Value: CCCCNC(=S)N/N=C/c1sccc1C
# Key: outcome, Value: 0.5726072607260726
# Key: key, Value: SDKIBDZIDPFNHT-UHFFFAOYSA-N
# Key: input, Value: CC(C)Cc1cc(C(=O)NCc2cccnc2)no1
# Key: outcome, Value: 0.19801980198019803
# Key: key, Value: CGVTXIMVAPAPNK-UHFFFAOYSA-N
# Key: input, Value: COC(=O)CC1NN=C2N(CCN2c2ccc(Cl)cc2)C1=O
# Key: outcome, Value: 0.416996699669967
# Key: key, Value: LWTPUALMLDLRFE-UHFFFAOYSA-N
# Key: input, Value: CCN1c2ncc(COc3cccc(C(=O)O)c3)cc2C(=O)N(C)c2ccc(Cl)nc21
# Key: outcome, Value: 0.34488448844884484
# Key: key, Value: OAGNFKCWXVXZJD-NDENLUEZSA-N
# Key: input, Value: Cc1c(NC(=S)N/N=C\\c2ccccc2O)c(=O)n(-c2ccccc2)n1C
# Key: outcome, Value: 0.5016501650165017
# Key: key, Value: YBVUWGYHDUMFEA-ZCFIWIBFSA-N
# Key: input, Value: C[C@@H](O)c1nc(-c2nc(-c3nc(CO)cs3)cs2)cs1
# Key: outcome, Value: 0.30544554455445544
# Key: key, Value: GASJOQPNNSMIFF-UHFFFAOYSA-N
# Key: input, Value: CCCCCCCCCCCC(=O)CCCC
# Key: outcome, Value: 0.5997760490334747
# Key: key, Value: LTLAIOBQBYOIBO-UHFFFAOYSA-N
# Key: input, Value: C=Cc1c(N)ncnc1N1CCC(c2nc(-c3ccc(C(F)(F)F)c(F)c3)cn2CCN2CCCC2)CC1
# Key: outcome, Value: 0.5792079207920792
# Key: key, Value: IZMHGQZQXOJLKP-NBVRZTHBSA-N
# Key: input, Value: O=C1/C(=N/c2ccc(O)cc2)C(Cl)C(=O)c2ccccc21
# Key: outcome, Value: 0.45008250825082513
# Key: key, Value: OBULHRRJFXTYED-NRFANRHFSA-N
# Key: input, Value: O=C(O)CC[C@H](NC(=O)c1cccc(-c2ccccc2)n1)C(=O)N1CCN(C(=O)OCCCC(F)(F)F)CC1
# Key: outcome, Value: 0.1608910891089109
# Key: key, Value: YVKRFZYIMJJBFA-UHFFFAOYSA-N
# Key: input, Value: CC(=O)Nc1c2c(nn1-c1ccccc1)C[S+]([O-])C2
# Key: outcome, Value: 0.2632013201320132
# Key: key, Value: QEYOHPDHFPXPHI-UHFFFAOYSA-N
# Key: input, Value: O=C(O)CSC(C(=O)Nc1ccc(Cl)cc1)c1ccccc1
# Key: outcome, Value: 0.23267326732673269
# Key: key, Value: GPOFEGFXZJVBAV-UHFFFAOYSA-N
# Key: input, Value: O=[N+]([O-])/N=C1\\NCCN1CCCCl
# Key: outcome, Value: 0.5198019801980198
# Key: key, Value: JLCVKQHIFSBODF-UHFFFAOYSA-N
# Key: input, Value: CCc1cc2[nH]c(=O)c3cnn(C4CCC4)c3c2cc1C(=O)N1CCN(CCC(F)(F)F)CC1
# Key: outcome, Value: 0.3622112211221122
# Key: key, Value: HFHMTIRZGGSTAO-UHFFFAOYSA-N
# Key: input, Value: O=C1c2cc(Cl)ccc2C2(c3ccccc3)SCCN12
# Key: outcome, Value: 0.5033003300330032
# Key: key, Value: ZQPKBYQQGAQUAK-BQYQJAHWSA-N
# Key: input, Value: O=C(O)c1ccc(OC/C=C/Cn2c(=O)n(C(c3ccccc3)c3ccccc3)c(=O)c3ccc(N4CCOCC4)cc32)cc1
# Key: outcome, Value: 0.5181518151815182
# Key: key, Value: PBQDGEKTDHPEJT-UHFFFAOYSA-N
# Key: input, Value: CNC(=O)c1cc(Oc2ccc(NC(=O)c3ccc(OC)cc3)cc2)ccc1N
# Key: outcome, Value: 0.4306930693069307
# Key: key, Value: DRFZSNBMKDNIIY-UHFFFAOYSA-N
# Key: input, Value: O=C(NCC1CC1)c1cc2c(s1)CCN2C(=O)c1ccc(F)cc1
# Key: outcome, Value: 0.22277227722772278
# Key: key, Value: SIVHAPVFQQZNKB-UHFFFAOYSA-N
# Key: input, Value: Nc1nnc(-c2ccc3[nH]cc(-c4cccc(=O)[nH]4)c3c2)s1
# Key: outcome, Value: 0.32673267326732675
# Key: key, Value: KEFVSMYJFCKVGF-DVVUODLYSA-N
# Key: input, Value: CC(=O)c1cc([C@H]2OC[C@@H](N=[N+]=[N-])[C@@H]2Cl)oc1C
# Key: outcome, Value: 0.21555280528052803
# Key: key, Value: MBQZCRIKUPDPSI-UHFFFAOYSA-N
# Key: input, Value: O=C(O)c1cccc(CN2C(=O)CC(c3ccccc3)Sc3ccccc32)c1
# Key: outcome, Value: 0.3032178217821782
# Key: key, Value: LZLAWIZBRZSTHY-UHFFFAOYSA-N
# Key: input, Value: O=C(CCC(NC(=O)c1cc(Cl)cc(Cl)c1)C(=O)N1CCC2(CCCC2)CC1)NCCN1CCOCC1
# Key: outcome, Value: 0.24504950495049505
# Key: key, Value: QDJHBNNBIMGPTN-HRQOGRHRSA-N
# Key: input, Value: Cc1cccc2c1OP(=O)(O[C@H]1C[C@H](n3cc([125I])c(=O)[nH]c3=O)O[C@@H]1CO)OC2
# Key: outcome, Value: 0.2627062706270627
# Key: key, Value: UYCUSHGDWRMTBH-ROUUACIJSA-N
# Key: input, Value: CCCCCCCCc1ccc(NC(=O)[C@@H](N)[C@@H](O)CC)cc1
# Key: outcome, Value: 0.5117161716171617
# Key: key, Value: ZURWTJLUKIDQPW-UHFFFAOYSA-N
# Key: input, Value: CC(C)N(CCC1(c2ccccc2)C(=O)NCN2CCCCC21)C(C)C
# Key: outcome, Value: 0.5742574257425742
# Key: key, Value: KPILUSAHPYZUAU-UHFFFAOYSA-N
# Key: input, Value: COc1ccc(C(=O)N2CCC3(CC2)CCN(c2ccncc2)CC3)cc1
# Key: outcome, Value: 0.6343941537010844
# Key: key, Value: MWDLEZWHBIBUQF-UHFFFAOYSA-N
# Key: input, Value: CNC(=O)Cc1ccc(C(=O)Nc2cccc(-c3ccc(-c4nc5cccc(C)c5[nH]4)s3)c2)cc1
# Key: outcome, Value: 0.5495049504950495
# Key: key, Value: PMFVVLDDNQOBSK-UHFFFAOYSA-N
# Key: input, Value: Cc1cc(NC(=O)c2c[nH]c3c(C(F)(F)F)cccc3c2=O)no1
# Key: outcome, Value: 0.26534653465346536
# Key: key, Value: JUPLUOFUEJQTPN-CMDGGOBGSA-N
# Key: input, Value: CS(=O)(=O)N(c1cc(C(F)(F)P(=O)(O)O)ccc1/C=C/c1ccccc1)S(C)(=O)=O
# Key: outcome, Value: 0.4608085808580858
# Key: key, Value: MLXZZQXUAVHVTH-UHFFFAOYSA-N
# Key: input, Value: O=c1[nH]c2ccccc2c2nc(-c3cccc(S(=O)(=O)N4CCCC4)c3)nn12
# Key: outcome, Value: 0.7145214521452145
# Key: key, Value: OULXRFUMARETNV-UHFFFAOYSA-N
# Key: input, Value: N#Cc1ccc(S(=O)(=O)N2CCN(c3ncccc3C(F)(F)F)CC2)cc1
# Key: outcome, Value: 0.6547029702970297
# Key: key, Value: RETSFBPUNNCKER-OPDITWGLSA-N
# Key: input, Value: C[C@H]1CN(c2c(F)cc3c(=O)c(C(=O)O)cn(C45CC(C4)C5)c3c2F)C[C@H]1CN
# Key: outcome, Value: 0.09088283828382837
# Key: key, Value: JHXBUZHKTRBUPU-HKUYNNGSSA-N
# Key: input, Value: CC#Cc1cncc(-c2csc([C@@H]3C[C@@H](c4c(C)noc4C)SC(N)=N3)c2)c1
# Key: outcome, Value: 0.3069306930693069
# Key: key, Value: DQUIDHIGYCDUAW-UHFFFAOYSA-N
# Key: input, Value: CCCCC(C)(O)C1CCC(N2C(=O)Cc3cc(OC)c(OC(C)C)cc3C2c2ccc(Cl)cc2)CC1
# Key: outcome, Value: 0.7009075907590759
# Key: key, Value: XZKSPTBEYGRIAW-UHFFFAOYSA-N
# Key: input, Value: COc1cc2c(N3CCN(C(=O)Nc4ccc(Oc5ccccc5)cc4)CC3)ncnc2cc1C
# Key: outcome, Value: 0.5536303630363036
# Key: key, Value: XRJVXAMPYWOKBH-UHFFFAOYSA-N
# Key: input, Value: O=C1C=CC(=O)N1CCNc1ncc(C(F)(F)F)cc1Cl
# Key: outcome, Value: 0.4646982555398397
# Key: key, Value: GUDSRFLRMQKQOH-UHFFFAOYSA-N
# Key: input, Value: N#Cc1ccc(Cn2c(CN3CCCC3)nc3ccccc32)cc1
# Key: outcome, Value: 0.9277227722772278
# Key: key, Value: NQOFDAVXLYCOSS-UWVGGRQHSA-N
# Key: input, Value: CC(=O)N[C@@H](CCN)C(=O)N[C@@H](CC(C)C)C(N)=O
# Key: outcome, Value: 0.08292079207920793
# Key: key, Value: UCLODDTXWGYADM-UHFFFAOYSA-N
# Key: input, Value: COc1ncc(N2CCOCC2)cc1S(=O)(=O)Nc1ccnc(-c2ccc(CN3CCCC3)cc2F)c1
# Key: outcome, Value: 0.40759075907590764
# Key: key, Value: YPOJPDVIGNKUGH-XDHOZWIPSA-N
# Key: input, Value: O=C(NCCCn1ccnc1)/C(=C\\c1cccnc1)NC(=O)c1cccc(Br)c1
# Key: outcome, Value: 0.2722772277227723
# Key: key, Value: UDYZLBDATCUMND-BGABXYSRSA-N
# Key: input, Value: CCO/N=C(\\c1ccc(Br)cc1)C1CCN(C2(C)CCN(C(=O)c3c(C)cc[nH]c3=O)CC2)CC1
# Key: outcome, Value: 0.3415841584158416
# Key: key, Value: JUFDKIHNAKWIPB-BXXZVTAOSA-N
# Key: input, Value: O=C(O)C(=O)OC[C@H]1OC(=O)[C@H](O)[C@@H]1O
# Key: outcome, Value: 0.08803630363036305
# Key: key, Value: NVOSPZNQVSARGS-UHFFFAOYSA-N
# Key: input, Value: COc1ccc(OC(=O)c2nc(SCc3ccccc3F)ncc2Cl)cc1
# Key: outcome, Value: 0.30825082508250823
# Key: key, Value: YUUYGPGETZPGDG-UHFFFAOYSA-N
# Key: input, Value: Fc1cccc(CNCC2Cn3nncc3CO2)c1
# Key: outcome, Value: 0.5346534653465347
# Key: key, Value: AAGONDJNRDWVLR-SANMLTNESA-N
# Key: input, Value: CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2c-1nc1ccc(OC)cc1c2C1CCCC1
# Key: outcome, Value: 0.4158415841584158
# Key: key, Value: ZELWNOUFNSTJBZ-UHFFFAOYSA-N
# Key: input, Value: CCOc1ccc2nc(NC(=O)C(=O)C(C(=O)c3ccccc3F)C3OC(=O)c4ccccc43)sc2c1
# Key: outcome, Value: 0.3633663366336634
# Key: key, Value: DVBXFRSRFUTZTN-UHFFFAOYSA-N
# Key: input, Value: CCc1ccc(I)c(CC)c1NC(=O)CN(CC(=O)O)CC(=O)O
# Key: outcome, Value: 0.14455445544554454
# Key: key, Value: ICZJHRYDJKYLQD-YTZAWJCFSA-N
# Key: input, Value: CO[C@H]1CN(C)C(=O)c2ccc(NC(=O)C3CC3)cc2OC[C@H](C)N(C(=O)c2ccccn2)C[C@H]1C
# Key: outcome, Value: 0.27722772277227725
# Key: key, Value: CXRJHASYZPXNEG-UHFFFAOYSA-N
# Key: input, Value: Cc1c(Cl)cccc1NC(=O)c1cc(NC(=O)c2ccccc2C(F)(F)F)cc2[nH]c(C3CCCC3)nc12
# Key: outcome, Value: 0.3712871287128713
# Key: key, Value: MQKSZWYYHGTHIV-UHFFFAOYSA-N
# Key: input, Value: CC(C)NS(=O)(=O)c1ccc(OCC(=O)Nc2ccccc2F)cc1
# Key: outcome, Value: 0.2524752475247525
# Key: key, Value: FIRIFVVVVQIBLD-UHFFFAOYSA-N
# Key: input, Value: CC1=NN(c2ccc(C(=O)O)cc2)C(=O)CC1
# Key: outcome, Value: 0.13366336633663367
# Key: key, Value: XVXCKHQWKUVAPE-UHFFFAOYSA-N
# Key: input, Value: CC(NC(=O)c1ccc(S(N)(=O)=O)cc1)C(=O)O
# Key: outcome, Value: 0.06930693069306931
# Key: key, Value: IFDQXIBLGLRXER-KTIHBUSBSA-N
# Key: input, Value: COC(=O)[C@@]12CCCN1[C@H](c1ccc(SC3CCCCC3)cc1)[C@H]1C(=O)N(C)C(=O)[C@H]12
# Key: outcome, Value: 0.18316831683168316
# Key: key, Value: LWMHQSNCXDHONB-UHFFFAOYSA-N
# Key: input, Value: O=C(c1ccccc1)N1CCN(S(=O)(=O)c2cccs2)CC1
# Key: outcome, Value: 0.3803630363036304
# Key: input, Value: O=C(CN1CCOCC1)NNc1nc(-c2ccccc2)c2cc(Br)ccc2n1
# Key: outcome, Value: 0.38514851485148516
# Key: key, Value: VUISAJWDMBCIQP-UHFFFAOYSA-N
# Key: input, Value: COc1ccc(C2=NN(CCCO)C(=O)C3CCCCC23)cc1OC
# Key: outcome, Value: 0.3080858085808581
# Key: key, Value: QXJMWFJCGMBRPK-UHFFFAOYSA-N
# Key: input, Value: COC(=O)Cn1c(=N)n(CCN2CCCCC2)c2ccccc21
# Key: outcome, Value: 0.5841584158415841
# Key: key, Value: RIJGXYIRUNBEJG-UHFFFAOYSA-N
# Key: input, Value: Oc1ccc(CC2CCN(CCC#Cc3ccccc3)CC2)cc1
# Key: outcome, Value: 0.8168316831683168
# Key: key, Value: HDYLUQPADNVNQG-UHFFFAOYSA-N
# Key: input, Value: COCCn1c(=O)c(-c2cn(C)c3ccccc23)nc2cnc(Oc3cccc(Cl)c3)nc21
# Key: outcome, Value: 0.7376237623762376
# Key: key, Value: NXBNYUSXDBHELA-DHZHZOJOSA-N
# Key: input, Value: COc1ccc(/C=C/C(=O)c2ccccc2O)cc1
# Key: outcome, Value: 0.13366336633663367
# Key: key, Value: JGOMOURYXGBGLP-UHFFFAOYSA-N
# Key: input, Value: COc1cc(C2CC(c3cc(OC)c(OC)c(OC)c3)=NN2C)ccc1O
# Key: outcome, Value: 0.26782178217821784
# Key: key, Value: SIMOEFIOKHUVBO-UHFFFAOYSA-N
# Key: input, Value: CC1(C)OCc2c(Nc3n[nH]c4c(Cl)cccc34)nc(-c3cn[nH]c3C(F)F)nc21
# Key: outcome, Value: 0.43564356435643564
# Key: key, Value: XVPZRKIQCKKYNE-UHFFFAOYSA-N
# Key: input, Value: Cn1c(Cc2ccccc2)nc(=O)c2ccccc21
# Key: outcome, Value: 0.7442244224422442
# Key: key, Value: UXLPJZGKAQRVTA-UHFFFAOYSA-N
# Key: input, Value: CCCOC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1cccc([N+](=O)[O-])c1
# Key: outcome, Value: 0.2773927392739275
# Key: key, Value: CGTBRZZQACOTSR-LSQHKTNHSA-N
# Key: input, Value: O=c1ncccn1[C@H]1[C@H](O)[C@H](O)[C@@]2(CO)C[C@H]12
# Key: outcome, Value: 0.1674917491749175
# Key: key, Value: OYTZWPYVHBHOPU-SFHVURJKSA-N
# Key: input, Value: CCc1nccn1CC(=O)c1ccc(-c2ccc(N3C[C@H](Cn4ccnn4)OC3=O)cc2F)cn1
# Key: outcome, Value: 0.34488448844884484
# Key: key, Value: QWMFOPZHDXETGS-ZVHZXABRSA-N
# Key: input, Value: O=C(N/N=C/c1ccccn1)c1cc(-c2ccncc2)nc2ccccc12
# Key: outcome, Value: 0.46782178217821785
# Key: key, Value: RSZWMKSWYWFHMX-SANMLTNESA-N
# Key: input, Value: CN(C)CCCN1C(=O)[C@H](Cc2ccccc2)N(Cc2ccc(-c3ccccc3-c3nn[nH]n3)cc2)C1=S
# Key: outcome, Value: 0.7764026402640263
# Key: outcome, Value: 0.36716171617161714
# Key: key, Value: BFNQHIJJIFTQCT-UHFFFAOYSA-N
# Key: input, Value: CC(O)(COc1ccc(F)cc1F)C(=O)Nc1ccc(C#N)cc1C(F)(F)F
# Key: outcome, Value: 0.3415841584158416
# Key: key, Value: NQEXFOOJALTUQI-UHFFFAOYSA-N
# Key: input, Value: CC(CNC(=O)c1ccccc1)(CNC(=O)c1ccccc1)[N+](=O)[O-]
# Key: outcome, Value: 0.18316831683168316
# Key: key, Value: BAZIZFOLMQRGMR-UHFFFAOYSA-N
# Key: input, Value: Cc1ccc(-n2ccn3c(SC(C)C(=O)Nc4ccc5c(c4)OCCO5)nnc3c2=O)cc1C
# Key: outcome, Value: 0.35148514851485146
# Key: key, Value: BXZCHELXYNXCDS-UHFFFAOYSA-N
# Key: input, Value: Nc1nc2[nH]c(C3CC3)c(Cc3ccc(Cl)c(Cl)c3)c(=O)n2n1
# Key: outcome, Value: 0.4282178217821782
# Key: key, Value: VYMNBUQVQUXHSM-UHFFFAOYSA-N
# Key: input, Value: CCCN(CCC)c1cc(C)nc2c(-c3ncc(N=O)cc3C)c(C)nn12
# Key: outcome, Value: 0.5775577557755776
# Key: key, Value: ULFGDQDWOJBMLY-YPMHNXCESA-N
# Key: input, Value: CC1(C)Oc2cc(C#N)sc2[C@@H](N2CCCC2=O)[C@@H]1O
# Key: outcome, Value: 0.3316831683168317
# Key: key, Value: VACBNLGJAQMVJK-UKTHLTGXSA-N
# Key: input, Value: O=C1Nc2ccccc2/C1=C\\C(=O)c1cccc(Cl)c1
# Key: outcome, Value: 0.48514851485148514
# Key: key, Value:
# Key: input, Value:
# Key: outcome, Value: 0.41089108910891087
# Key: key, Value: LDXDMBVFSOGIIJ-NRXMAPPISA-N
# Key: input, Value: COc1ccc(/N=C2C(=N/c3ccc(OC)cc3)/N(c3ccccc3)C(=S)N/2N=C=C2Sc3ccccc3N2C)cc1
# Key: outcome, Value: 0.7334983498349836
# Key: key, Value: IIRVXNJEGFDTAK-UHFFFAOYSA-N
# Key: input, Value: O=C(CCN1C(=O)c2cccc3cccc(c23)C1=O)NCc1cccnc1
# Key: outcome, Value: 0.4158415841584158
# Key: key, Value: KJVFQLVWOAZHEV-UHFFFAOYSA-N
# Key: input, Value: CCCCNC(=O)CSc1nc2cc3c(cc2c(=O)n1Cc1ccco1)OCO3
# Key: outcome, Value: 0.4430693069306931
# Key: key, Value: OXYCNDUOAUAOAC-IGMJJTELSA-N
# Key: input, Value: COC(=O)[C@@]1(C)[C@H]2C(=O)N(C)C(=O)[C@H]2[C@H]2CN=C(SCc3ccc(C)cc3)N21
# Key: outcome, Value: 0.31683168316831684
# Key: key, Value: QRYRSVDNNGPOCP-UHFFFAOYSA-N
# Key: input, Value: C=CCNC(=O)C(C)(C(C)C)N(C(=O)c1cccnc1)C1CC1
# Key: outcome, Value: 0.16947194719471947
# Key: key, Value: IUFLCCGSBWWBGH-UHFFFAOYSA-N
# Key: key, Value: SVRJEAMALKPJOQ-UHFFFAOYSA-N
# Key: input, Value: O=C(COC(=O)CN1C(=O)NC2(CCCCC2)C1=O)Nc1cc(F)ccc1F
# Key: outcome, Value: 0.33003300330033
# Key: key, Value: NDINQOKZIDQTBN-UHFFFAOYSA-N
# Key: input, Value: O=C(OCc1cccs1)c1cc2c(o1)C(=O)c1ccccc1C2=O
# Key: outcome, Value: 0.3308580858085809
# Key: key, Value: ZYODXRYBYZMUNL-UHFFFAOYSA-N
# Key: input, Value: COC(=O)CCc1ccc(C)cc1
# Key: outcome, Value: 0.2784653465346535
# Key: key, Value: QBDOFAGOTWCKQB-UHFFFAOYSA-N
# Key: input, Value: COc1ccc(Cn2c(NCCNC(=N)N)nc(=O)n(CCc3ccccc3)c2=O)cc1
# Key: outcome, Value: 0.7207920792079208
# Key: key, Value: INNWZDNVOIAPRP-UHFFFAOYSA-N
# Key: input, Value: CCOP(=O)(OCC)C1(P(=O)(OCC)OCC)CC(C(=O)CC)=NN1
# Key: outcome, Value: 0.2330858085808581
# Key: key, Value: IDOHVXBVCIPPSW-HOTGVXAUSA-N
# Key: input, Value: C[C@H]1COCCN1c1nc(N2CCOC[C@@H]2C)c2nc(-c3ccc(-c4ncc[nH]4)cc3)[nH]c2n1
# Key: outcome, Value: 0.30816831683168316
# Key: key, Value: KELKEHFTJFLDAM-UHFFFAOYSA-N
# Key: input, Value: O=C(Nc1ccc(OC(F)(F)F)cc1)NC1COc2ccccc2C1
# Key: outcome, Value: 0.4975247524752475
# Key: key, Value: RUGBZCTWKBEUNI-UHFFFAOYSA-N
# Key: input, Value: Cc1cc(C)nc(NC(=S)N2CCN(c3ccc4ccccc4c3)CC2)c1
# Key: outcome, Value: 0.6641914191419143
# Key: key, Value: OAVFKAHCLBNXSU-UHFFFAOYSA-N
# Key: input, Value: Cc1nnc(SC(C)C(=O)Nc2nccs2)s1
# Key: outcome, Value: 0.18316831683168316
# Key: key, Value: QLPJOBBIJIWDOA-UHFFFAOYSA-N
# Key: input, Value: NC1=C(c2nc3ccccc3s2)C(=O)CN1NC(=O)c1c[nH]c2ccccc12
# Key: outcome, Value: 0.3584394153701085
# Key: key, Value: JAURGPIILHRUCZ-WEVVVXLNSA-N
# Key: input, Value: C/C(C#N)=C\\c1ccc(C)cc1Cl
# Key: outcome, Value: 0.26487505893446484
# Key: key, Value: OYELBKDRZUAMQY-SHHOIMCASA-N
# Key: input, Value: COc1ccc(CC(/C(=N/OCCCCC(=O)O)C2CCCCC2)n2ccnc2)cc1
# Key: outcome, Value: 0.4064356435643564
# Key: key, Value: DRHSVFXMBSQDIC-REZTVBANSA-N
# Key: input, Value: O=C1Nc2ccc(Cl)cc2/C1=N/N=C/c1ccc(O)c(O)c1
# Key: outcome, Value: 0.3886138613861386
# Key: key, Value: MRMNCFGODMCHHJ-UHFFFAOYSA-N
# Key: input, Value: Cc1nc(Nc2nc(CSc3ccc(Cl)cc3)cc(=O)[nH]2)nc2ccccc12
# Key: outcome, Value: 0.6002475247524752
# Key: key, Value:
# Key: input, Value:
# Key: outcome, Value: 0.25495049504950495
# Key: key, Value: JMRQLQZCVRXVBF-DPQHJISKSA-N
# Key: input, Value: C=C(CC[C@@H](C)[C@H]1CC=C2C3=C([C@@H](O)[C@H](OC(C)=O)[C@@]21C)[C@@]1(C)C[C@@H](O)[C@H](OC(=O)CCC(=O)O)C(C)(C)[C@@H]1CC3)C(C)C
# Key: outcome, Value: 0.13927392739273925
# Key: key, Value: PKSYYDVTKCWIMK-QJLXOANVSA-N
# Key: input, Value: CO[C@]1(c2cc(F)cc(Sc3ccc(/C(C)=N/O)cc3)c2)CCO[C@@H](C)C1
# Key: outcome, Value: 0.5008250825082509
# Key: key, Value: ILBNDUAYPWIWNI-CYBMUJFWSA-N
# Key: input, Value: Cc1c(-c2ccn[nH]2)sc2c(N[C@@H]3CCNC3)nc(-c3ccncc3)nc12
# Key: outcome, Value: 0.5948844884488448
# Key: key, Value: ZCODZCCHEGPLFA-UHFFFAOYSA-N
# Key: input, Value: CCC1C(=O)N2C=CSC2=[N+](Cc2ccc(Cl)cc2)C1=O
# Key: outcome, Value: 0.6267326732673267
# Key: key, Value: DHJSIGLFEZHWTN-UHFFFAOYSA-N
# Key: input, Value: COc1cc2[nH]c(=O)c(-c3cccs3)c(-c3cccc(-c4ccccn4)c3)c2cc1OC
# Key: outcome, Value: 0.5668316831683168
# Key: key, Value: VQKNVDMTYTWAPP-RGVLZGJSSA-N
# Key: input, Value: COc1ccc(N2C(=O)CC(SC(=N)N/N=C(\\C)c3cccs3)C2=O)cc1
# Key: outcome, Value: 0.3564356435643564
# Key: key, Value: MHJKYBXJQUFCAY-UHFFFAOYSA-N
# Key: input, Value: O=C1Nc2[nH]nc(C3CCN(c4cnc(C(F)(F)F)cn4)CC3)c2C(O)(C(F)(F)F)C1O
# Key: outcome, Value: 0.37285478547854783
# Key: key, Value: NWJKKFOUUINEJW-UHFFFAOYSA-N
# Key: input, Value: O=C(c1cccc(-c2ccccc2F)c1)N1CCc2c([nH]c3ccccc23)C1
# Key: outcome, Value: 0.7158415841584158
# Key: key, Value: XUXIHIPUVGXTQG-NRFANRHFSA-N
# Key: input, Value: N=C(N)N1CCC[C@H]1c1nc(-c2ccc3cc(OCC(=O)c4ccc(C(F)(F)F)cc4)ccc3c2)no1
# Key: outcome, Value: 0.3886138613861386
# Key: key, Value: QUVGJMKWHNSLBX-UHFFFAOYSA-N
# Key: input, Value: CCN(CC)CCN(CC)c1ccc2cc(C(=N)N)c(=O)oc2c1
# Key: outcome, Value: 0.3902640264026403
# Key: key, Value: GZAPVKSQRTZSJU-UHFFFAOYSA-N
# Key: input, Value: OC(Cn1ccnc1)(c1ccc(F)cc1)c1ccccc1-c1ccncc1
# Key: outcome, Value: 0.5154702970297029
# Key: key, Value: GDYUSSFBUVJSFX-UHFFFAOYSA-N
# Key: input, Value: CN(c1ccc(Cl)cc1)S(=O)(=O)c1cccc(C(=O)Nc2cc(Cl)cnn2)c1
# Key: outcome, Value: 0.5816831683168316
# Key: input, Value: O=c1[nH]nc(Cc2ccc3ccccc3n2)c2ccccc12
# Key: outcome, Value: 0.806930693069307
# Key: key, Value: WRZWNGDNMKKPBC-UHFFFAOYSA-N
# Key: input, Value: O=C(c1ccccc1)N(CC(O)Cn1c2ccccc2c2ccccc21)c1ccc(C(F)(F)F)cc1
# Key: outcome, Value: 0.5594059405940595
# Key: key, Value: ABQSJCCISLWTEW-UHFFFAOYSA-N
# Key: input, Value: COc1cc(OC)cc(-c2cc3cnc(NCCCN4CCN(C)CC4)cc3nc2NC(=O)NC(C)(C)C)c1
# Key: outcome, Value: 0.5301155115511552
# Key: key, Value: MYEIDQDVSWLKKZ-UHFFFAOYSA-N
# Key: input, Value: O=C(O)c1ccnc(-n2nccc2OC2CCCc3cc(Cl)ccc32)c1
# Key: outcome, Value: 0.26402640264026406
# Key: key, Value: VGRLQPPWTVAVCL-JXMROGBWSA-N
# Key: input, Value: COc1cccc(/C=C/C(=O)OCC(=O)Nc2ccc(Cl)c(S(=O)(=O)N(C)C)c2)c1
# Key: outcome, Value: 0.40924092409240925
# Key: key, Value: RYIDKSWQOIOIRY-WKILWMFISA-N
# Key: input, Value: N[C@H]1CC[C@H](NC(=O)c2nc(Br)c3cccnc3c2NCc2ccc(F)cc2)CC1
# ...
# Key: key, Value: DKDDVQGTCDYMBJ-UHFFFAOYSA-N
# Key: input, Value: Cc1nnc(SCC(=O)Nc2sccc2C(N)=O)n1Cc1ccccc1
# Key: outcome, Value: 0.28217821782178215
# Key: key, Value: DEQYSMOBGAWMAL-UHFFFAOYSA-N
# Key: input, Value: COC(=O)C1C(=O)NCC1c1ccc(OC)cc1
# Key: outcome, Value: 0.2103960396039604
# Key: key, Value: FTZUJTIVZAUIDZ-UHFFFAOYSA-N
# Key: input, Value: Cn1nc(C(=O)OCC(=O)NCc2ccc(Cl)cc2)c2ccccc2c1=O
# Key: outcome, Value: 0.4282178217821782
# Key: key, Value: CIOQUUUMMYPGKD-UHFFFAOYSA-N
# Key: input, Value: CC(C)c1ccc(N2C(=O)c3ccccc3C2=O)cc1
# Key: outcome, Value: 0.6622112211221122
# Key: key, Value: KAMDIPZCMWRTLU-QXMHVHEDSA-N
# Key: input, Value: CCCCCCC/C=C\\CCCCCCCC(=O)OC(COC(C)C)COP(C)(=O)F
# Key: outcome, Value: 0.4806105610561056
# Key: key, Value: ZTJBRLHJSDGEDC-WYXQGNMASA-N
# Key: input, Value: CC(C)OC(=O)[C@H](C)NP(=O)(OC[C@H]1O[C@@H](n2ccc(=O)[nH]c2=O)[C@](F)(Br)[C@@H]1O)Oc1ccccc1
# Key: outcome, Value: 0.4836358635863586
# Key: key, Value: IUPDIFIBOIPXEL-UHFFFAOYSA-N
# Key: input, Value: CC(C)n1nccc1NC(=O)Nc1ccccc1
# Key: outcome, Value: 0.20701320132013198
# Key: key, Value: BDKCBNKKZXWGBC-UHFFFAOYSA-N
# Key: input, Value: O=C1NCc2cc(C#Cc3ccc(F)cc3)ccc21
# Key: outcome, Value: 0.4620462046204621
# Key: key, Value: ZHTZIUSLOIZPHL-KNTDEHBRSA-N
# Key: input, Value: COc1ccc2c3c1O[C@H]1[C@]4(OC)CC[C@@]5(C[C@@H]4CNC(=O)/C=C/c4ccccc4)[C@@H](C2)N(C)CC[C@]315
# Key: outcome, Value: 0.5618811881188119
# Key: key, Value: NMSIJMKFXSWEOR-UHFFFAOYSA-N
# Key: input, Value: CC(=O)Nc1ccc(S(=O)(=O)N(C)CC(=O)OC(C)C(=O)NC2CCCC2)cc1
# Key: outcome, Value: 0.20833333333333334
# Key: key, Value: ZZNGBIBRJZOOQT-UHFFFAOYSA-N
# Key: input, Value: Cc1nn(C2CCS(=O)(=O)C2)c(C)c1CN(C)C(=O)c1ccccc1
# Key: outcome, Value: 0.4348184818481849
# Key: key, Value: JYEYMCMIADJBBB-DJKKODMXSA-N
# Key: input, Value: O=C(O)c1ccccc1O/N=C/c1cccc(C(F)(F)F)c1
# Key: outcome, Value: 0.2400990099009901
# Key: key, Value: HIOWDZZIBUXEHQ-UHFFFAOYSA-N
# Key: input, Value: Clc1cccc(C2ON=C(c3ccccc3Cl)O2)c1
# Key: outcome, Value: 0.7351485148514851
# Key: key, Value: ZOQHBTXVQKGTDU-UHFFFAOYSA-N
# Key: input, Value: CC1(C)NC(N)=NC(=N)N1OCCCOc1cccc(Cl)c1
# Key: outcome, Value: 0.6254125412541254
# Key: key, Value: VGXAUABGTLEXCN-UHFFFAOYSA-N
# Key: input, Value: CCSc1nnnc2c1sc1nc(N3CCOCC3)c3c(c12)CCCC3
# Key: outcome, Value: 0.4801980198019802
# Key: key, Value: ISYQRUPHFNFRMZ-UHFFFAOYSA-N
# Key: input, Value: c1ccc(CN(c2ccc3[nH]ccc3c2)C2CCCNC2)cc1
# Key: outcome, Value: 0.7277227722772277
# Key: key, Value: NYEUCFWPMRQBAH-QFIPXVFZSA-N
# Key: input, Value: O=C(O)COc1cccc2c1CC[C@H](Cn1cc(C(c3ccccc3)c3ccccc3)ccc1=O)C2
# Key: outcome, Value: 0.5148514851485149
# Key: key, Value: CZQJZCHADYYLAF-FDDCHVKYSA-N
# Key: input, Value: COc1ccc(OC[C@@]2(c3ccccc3)C[C@H]2C(=O)Nc2cc(C)on2)cc1OC
# Key: outcome, Value: 0.47029702970297027
# Key: key, Value: BSZYGMJIKVVIQH-UHFFFAOYSA-N
# Key: input, Value: CC(=C(c1ccccc1)c1ccccc1)c1ccc([S+](C)(=N)[O-])cc1
# Key: outcome, Value: 0.620049504950495
# Key: key, Value: SEBALDIRDDKSDU-UHFFFAOYSA-N
# Key: input, Value: N#Cc1cccc(C2C3=C(CCC3=O)NC3=C2S(=O)(=O)CC3)n1
# Key: outcome, Value: 0.2599009900990099
# Key: key, Value: KGIUTIANTQIKIP-GXDHUFHOSA-N
# Key: input, Value: CC(=O)N1CCN(C2=NC(=O)/C(=C\\c3ccccc3O)S2)CC1
# Key: outcome, Value: 0.21617161716171615
# Key: key, Value: UPTUKJDQDVLZKI-UHFFFAOYSA-N
# Key: input, Value: O=c1c2ccccc2nc(-c2ccc(OS(=O)(=O)O)cc2)n1CCCCn1cc(Cn2c(-c3cccc(OS(=O)(=O)O)c3)nc3ccccc3c2=O)nn1
# Key: outcome, Value: 0.5688943894389439
# Key: key, Value: YUTIWGCQKKKLLJ-UHFFFAOYSA-N
# Key: input, Value: CN(C)c1ccc2nc(N)nc(N)c2c1Cl
# Key: outcome, Value: 0.15264026402640263
# Key: key, Value: BSBPRYCGNNRLJB-LUEVFRQOSA-N
# Key: input, Value: CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CCC(=O)O)C(=O)N[C@H](C(=O)NN(CC(=O)O)C(=O)/C=C/C(=O)OCc1ccccc1)[C@@H](C)O
# Key: outcome, Value: 0.5264026402640264
# Key: key, Value: KHPCIHZXOGHCLY-UHFFFAOYSA-N
# Key: input, Value: Nc1ccc(-c2cnc(N)c(-c3ccc(Cl)cc3)c2)cn1
# Key: outcome, Value: 0.5915841584158416
# Key: key, Value: SMXTVTKALJLBPD-UHFFFAOYSA-O
# Key: input, Value: CNc1cc(/C=C/c2c(C)[nH]c3ccccc23)[n+](C)c2ccccc12
# Key: outcome, Value: 0.7887788778877887
# Key: key, Value: VDHGNLSURRPLAT-LOSJGSFVSA-N
# Key: input, Value: O=C(N[C@@H](C(=O)N1CCC[C@H]1C(=O)Nc1nc(-c2ccccc2)cs1)c1ccccc1)C1CCCCC1
# Key: outcome, Value: 0.1963696369636964
# Key: key, Value: XNIBFPUVFRGWGS-UHFFFAOYSA-N
# Key: input, Value: Cc1c(C(F)(F)F)noc1OCC(=O)N(C)c1cccc([N+](=O)[O-])c1
# Key: outcome, Value: 0.2632013201320132
# Key: key, Value: ATOOTTCWUJAOSU-UHFFFAOYSA-N
# Key: input, Value: Cc1c(C(=O)CNc2nccs2)[n+]([O-])c2ccccc2[n+]1[O-]
# Key: outcome, Value: 0.30363036303630364
# Key: key, Value: KCXGPDFLJSOKIZ-UHFFFAOYSA-N
# Key: input, Value: CCSCc1c(C)[nH]c(=O)c(I)c1Sc1cc(C)cc(C)c1
# Key: outcome, Value: 0.31683168316831684
# Key: key, Value: OFXXBNQORFRNFR-UHFFFAOYSA-N
# Key: input, Value: OCCC1CN(Cc2cc3c(cc2Cl)OCO3)CCN1C1CCCC1
# Key: outcome, Value: 0.5816831683168316
# Key: key, Value: BVHSBJDVWQILPE-UHFFFAOYSA-N
# Key: input, Value: c1ccc2c(c1)c1c(n2CCCN2CCCCC2)CN(CCCc2ccncc2)CC1
# Key: outcome, Value: 0.9331683168316832
# Key: key, Value: FYSGPFWNLRRMDV-UHFFFAOYSA-N
# Key: input, Value: CCC(=O)N(Cc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Cc1cnccc1-c1ccccc1
# Key: outcome, Value: 0.5882838283828383
# Key: key, Value: SLUPUHLVPJEPNB-UHFFFAOYSA-N
# Key: input, Value: COc1ccc2c(c1)c1cc(OC)c(OC)cc1c1cc3[n+](cc21)CCC3
# Key: outcome, Value: 0.5144939493949395
# Key: key, Value: QCEFOIDJHJPYIB-MDWZMJQESA-N
# Key: input, Value: CC12CCC(C/C1=N\\NC(N)=O)C2(C)C
# Key: outcome, Value: 0.12112211221122111
# Key: key, Value: CTICJGZXKHCHST-IUPBHXKESA-N
# Key: input, Value: C[C@H]1O[C@@H](COC(=O)c2ccccc2)O[C@@H]1n1cc(F)c(N)nc1=O
# Key: outcome, Value: 0.3056930693069307
# Key: key, Value: AEBGVVBYFUZUED-UHFFFAOYSA-N
# Key: input, Value: COc1ccc(-c2ccc3ccc(OC)cc3[o+]2)cc1
# Key: outcome, Value: 0.7541018387553041
# Key: key, Value: ZZWJASQZCDWPFG-UHFFFAOYSA-N
# Key: input, Value: CCn1ncnc1CN1CCC(CNC(=O)c2cccc(C)n2)C1
# Key: outcome, Value: 0.49504950495049505
# Key: key, Value: VRYMTAVOXVTQEF-UHFFFAOYSA-N
# Key: input, Value: CC(=O)Oc1cc(C(C)C)c(OCCN(C)C)cc1C
# Key: outcome, Value: 0.2924328147100424
# Key: key, Value: XTJRPOFKSXCKPF-UHFFFAOYSA-N
# Key: input, Value: Nc1nc2[nH]c(-c3ccccc3)c(-c3ccccc3)c2c(=O)[nH]1
# Key: outcome, Value: 0.3869636963696369
# Key: key, Value: BKDMICIBSRKEST-UHFFFAOYSA-P
# Key: input, Value: C[N+]1(CCC(=O)Nc2ccc3c(c2)C(=O)c2cc(NC(=O)CC[N+]4(C)CCCCC4CO)ccc2-3)CCCCC1CO
# Key: outcome, Value: 0.3217821782178218
# Key: key, Value: MFOZPYTUDQEMMW-UHFFFAOYSA-N
# Key: input, Value: O=C(CCCCN1CCN(CC2CC(=O)c3ccoc3C2)CC1)c1ccc(F)cc1
# Key: outcome, Value: 0.6872937293729372
# Key: key, Value: DWEBYMJLRCWIRS-UHFFFAOYSA-N
# Key: input, Value: CNc1nc2cn(-c3cccc(OC)c3)c(=O)c-2c[nH]1
# Key: outcome, Value: 0.41089108910891087
# Key: key, Value: QXXWFWUGWOXHGQ-UHFFFAOYSA-N
# Key: input, Value: CC(Cn1cccn1)NCc1csc(-c2ccc3c(c2)OCO3)n1
# Key: outcome, Value: 0.3704620462046204
# Key: key, Value: TZZNDQGUMPILBH-SEYXRHQNSA-N
# Key: input, Value: COC(=O)O/C(=C1\\C(=O)N(C(N)=O)c2cc(Cl)c(F)cc21)c1cccs1
# Key: outcome, Value: 0.25
# Key: key, Value: UOUNOYWIBROXIZ-FBCYGCLPSA-N
# Key: input, Value: CCOc1cc(Cl)c(Cl)c(/C=N/c2ccc3[nH]c(=O)[nH]c3c2)c1O
# Key: outcome, Value: 0.332013201320132
# Key: key, Value: VQCCNHUJVQLJNN-UHFFFAOYSA-N
# Key: input, Value: O=C(c1ccc(-c2cc3cc(Br)ccc3oc2=O)nc1)c1ccccc1O
# Key: outcome, Value: 0.41089108910891087
# Key: key, Value: QYMYUAYALRNHHU-ULIFNZDWSA-N
# Key: input, Value: CCc1nc(N)nc(N)c1-c1ccc(Cl)c(/N=N/N(CCOC(C)=O)Cc2cc(OC)c(OC)c(OC)c2)c1
# Key: outcome, Value: 0.2957920792079208
# Key: key, Value: SECBYWGLDGHJLN-UHFFFAOYSA-N
# Key: input, Value: O=C(Cn1nc(Cc2ccccc2)c2ccccc2c1=O)Nc1cccc(C(F)(F)F)c1
# Key: outcome, Value: 0.504950495049505
# Key: key, Value: WCBHWWCRMPMBTH-UHFFFAOYSA-N
# Key: input, Value: c1cc(CN2CCNCCCNCCNCC2)ccc1CN1CCNCCCNCCNCC1
# Key: outcome, Value: 0.5808580858085808
# Key: key, Value: GDCWMJWWRYTXNY-UHFFFAOYSA-N
# Key: input, Value: CC(C)C(=O)Nc1ccc2nc(-c3cccc(Cl)c3Cl)oc2c1
# Key: outcome, Value: 0.44413012729844414
# Key: key, Value: RWDSZWNVYRUBLM-UHFFFAOYSA-N
# Key: input, Value: COc1c(C2CCC2)ccc(-c2ncc(N)nc2C#N)c1F
# Key: outcome, Value: 0.42739273927392746
# Key: key, Value: YCBVYRSRHHEJAL-MLNSLSNSSA-N
# Key: input, Value: C#CCCOC(=O)/C=C(C)/C=C/CC(C)CCCC(C)(C)OC
# Key: outcome, Value: 0.2899575671852899
# Key: key, Value: XUSDPLZITNXIBP-UHFFFAOYSA-N
# Key: input, Value: CCOc1ccc2c(c1)=[N+]([O-])C(C)(C)[N+]=2[O-]
# Key: outcome, Value: 0.35016501650165016
# Key: key, Value: FANFUDBBDAWKMK-LHWQALLBSA-N
# Key: input, Value: N=c1c2ccsc2nc2n1CC/C2=C\\c1ccccc1Br
# Key: outcome, Value: 0.452970297029703
# Key: key, Value: LGNRWEUQQPIDQM-UHFFFAOYSA-N
# Key: input, Value: COc1ccc2c(c1)CC(c1nc3c(F)cc(-c4ccnc(N)n4)cc3[nH]1)CO2
# Key: outcome, Value: 0.3217821782178218
# Key: key, Value: NSCLZWBWQLOXFQ-UHFFFAOYSA-N
# Key: input, Value: CSCCNC1=C(F)C(=O)c2c(F)c(F)c(F)c(F)c2C1=O
# Key: outcome, Value: 0.3435093509350935
# Key: key, Value: PVPJLZORNPIRDJ-UHFFFAOYSA-N
# Key: input, Value: O=C(COc1ccccc1C(=O)Nc1ccccc1)Nc1ccc(-c2ccccc2)cc1
# Key: outcome, Value: 0.49133663366336633
# Key: key, Value: HHWIWTYLCSYMPN-UHFFFAOYSA-N
# Key: input, Value: Nc1nc(N)c2cc(S(=O)(=O)Nc3ccc(Cl)c(Cl)c3)ccc2n1
# Key: outcome, Value: 0.599009900990099
# Key: key, Value: RGKVPYQYBUAAEH-UHFFFAOYSA-N
# Key: input, Value: CCCn1c(-c2cnc(Nc3ccc(C)nc3)c(Cl)c2)nc2cccc(Cl)c21
# Key: outcome, Value: 0.7594884488448844
# Key: key, Value: VTRFEMUYHTXFEQ-UHFFFAOYSA-N
# Key: input, Value: CN(Cc1cccc2ccccc12)Cn1nc(-c2ccncc2)oc1=O
# Key: outcome, Value: 0.7788778877887788
# Key: key, Value: QDFOYTHIYBSDPW-RGAOVNQFSA-N
# Key: input, Value: O=C(N[C@@H](CSCc1ccccc1)C(=O)Nc1ccc(C2S/C(=N\\c3cccc(F)c3)N(Cc3ccco3)C2=O)cc1)OCc1ccccc1
# Key: outcome, Value: 0.5321782178217822
# Key: key, Value: YZQZXLROYFNFQE-QTGUNEKASA-N
# Key: input, Value: CN1CC[C@]23CCCC[C@H]2[C@H]1Cc1ccc(Oc2ccccc2F)cc13
# Key: outcome, Value: 0.8811881188118812
# Key: key, Value: PRGIOMDFWSHPTC-QPEQYQDCSA-N
# Key: input, Value: O=C(CN1C(=O)/C(=C/c2ccco2)SC1=S)Nc1ccc(C(=O)O)c(O)c1
# Key: outcome, Value: 0.3594059405940594

# %%
import csv
import re

def extract_keys_and_values_from_text(file_path):
    key_value_pairs = []
    with open(file_path, 'r') as file:
        text = file.read()
        # Define a regular expression pattern to find key-value pairs
        pattern = r'"key":\s*"(.*?)".*?"input":\s*"(.*?)".*?"outcome":\s*\[\s*(\d+\.\d+)\s*\]'
        matches = re.findall(pattern, text, re.DOTALL)
        for match in matches:
            key_value_pairs.append(("key", match[0]))
            key_value_pairs.append(("input", match[1]))
            key_value_pairs.append(("outcome", float(match[2])))
    return key_value_pairs

def write_to_csv(key_value_pairs, output_file):
    with open(output_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Key', 'Input', 'Outcome'])
        for i in range(0, len(key_value_pairs), 3):
            writer.writerow([key_value_pairs[i][1], key_value_pairs[i+1][1], key_value_pairs[i+2][1]])

file_path = os.path.abspath('../data/row_output.txt')
output_file = os.path.abspath('../data/final_output.scv')
key_value_pairs = extract_keys_and_values_from_text(file_path)
write_to_csv(key_value_pairs, output_file)

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2017.3 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/tsion/miniconda3/envs/ersilia/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 233.1 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %% [markdown]
# # Test output and analyse

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
output_file = os.path.abspath('../data/final_output.scv')

# Assuming your CSV file is named 'predictions.csv' and the predicted values are in the third column
df = pd.read_csv(output_file, header=None, names=['Key', 'Input', 'Outcome'])

# Plotting a histogram
plt.figure(figsize=(10, 6))
plt.hist(df['Outcome'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Predicted Values')
plt.ylabel('Frequency')
plt.title('Histogram of Predicted Values')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Plotting a density plot
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Prediction'], shade=True, color='skyblue')
plt.xlabel('Predicted Values')
plt.ylabel('Density')
plt.title('Density Plot of Predicted Values')
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/ersilia/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2305, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Outcome"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 9
#       6 df = pd.read_csv(output, names=["Key", "Input", "Outcome"])
#       8 # Convert Outcome column to numeric
# ----> 9 df["Outcome"] = pd.to_numeric(df["Outcome"])
#      11 # Basic analysis
#      12 print("Basic Analysis:")
#
# File ~/miniconda3/envs/ersilia/lib/python3.10/site-packages/pandas/core/tools/numeric.py:183, in to_numeric(arg, errors, downcast)
#     181 coerce_numeric = errors not in ("ignore", "raise")
#     182 try:
# --> 183     values, _ = lib.maybe_convert_numeric(
#     184         values, set(), coerce_numeric=coerce_numeric
#     185     )
#     186 except (ValueError, TypeError):
#     187     if errors == "raise":
#
# File ~/miniconda3/envs/ersilia/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2347, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Outcome" at position 0
